# %%
import main

# %%
print(data.columns)
# Out:
# Index(['Company', 'Rank', 'Location', 'State', 'Specialism',
#        'Total Compensation', 'Base', 'Stock', 'Bonus'],
#       dtype='object')

# %%
data
# Out:
#      Company   Rank           Location   State  \
# 0   Facebook     E3     Menlo Park, CA      CA
# 1   Facebook     E3     Menlo Park, CA      CA
# 2   Facebook     E3     Menlo Park, CA      CA
# 3   Facebook     E3        Seatlle, WA      WA
# 4   Facebook     E3     Menlo Park, CA      CA
# 5   Facebook     E3     Menlo Park, CA      CA
# 6   Facebook     E3     Menlo Park, CA      CA
# 7   Facebook     E3        Seatlle, WA      WA
# 8   Facebook     E3        Seatlle, WA      WA
# 9   Facebook     E3     Menlo Park, CA      CA
# 10    Google  L3/T3  Mountain View, CA      CA
# 11    Google  L3/T3      Sunnyvale, CA      CA
# 12    Google  L3/T3       New York, NY      NY
# 13    Google  L3/T3      San Bruno, CA      CA
# 14    Google  L3/T3      Kitchener, ON  Canada
# 15    Google  L3/T3  Mountain View, CA      CA
#
#                         Specialism Total Compensation    Base   Stock  Bonus
# 0   Distributed Systems (Back-End)          $232,000   110000   37000  85000
# ...

# %%
print(data)
# Out:
#      Company   Rank           Location   State  \
# 0   Facebook     E3     Menlo Park, CA      CA
# 1   Facebook     E3     Menlo Park, CA      CA
# 2   Facebook     E3     Menlo Park, CA      CA
# 3   Facebook     E3        Seatlle, WA      WA
# 4   Facebook     E3     Menlo Park, CA      CA
# 5   Facebook     E3     Menlo Park, CA      CA
# 6   Facebook     E3     Menlo Park, CA      CA
# 7   Facebook     E3        Seatlle, WA      WA
# 8   Facebook     E3        Seatlle, WA      WA
# 9   Facebook     E3     Menlo Park, CA      CA
# 10    Google  L3/T3  Mountain View, CA      CA
# 11    Google  L3/T3      Sunnyvale, CA      CA
# 12    Google  L3/T3       New York, NY      NY
# 13    Google  L3/T3      San Bruno, CA      CA
# 14    Google  L3/T3      Kitchener, ON  Canada
# 15    Google  L3/T3  Mountain View, CA      CA
#
#                         Specialism Total Compensation    Base   Stock  Bonus
# 0   Distributed Systems (Back-End)          $232,000   110000   37000  85000
# ...
